# %% [markdown]
# ### Importo paquetes

# %%
import os
path = os.path.join(os.path.expanduser('~'), 'Documents/Proyectos/herramientas/')
import matplotlib.font_manager as font_manager
from matplotlib import rcParams
import matplotlib.pyplot as plt
import numpy as np

# %%
# Definimos fuente para los graficos
font_dir = [path + 'Archivo/']
for font in font_manager.findSystemFonts(font_dir):
    font_manager.fontManager.addfont(font)
rcParams['font.family'] = 'Archivo'
font_manager.fontManager

# %% [markdown]
# ### Cargo resultados

# %%
results_beto = [ {'eval_loss': 1.424133539199829,  'eval_accuracy': 0.7864768683274022,  'eval_f1': 0.6610169491525424,  'eval_f1 macro': 0.7525863966541932,  'eval_precision': 0.6724137931034483,  'eval_recall': 0.65,  'eval_runtime': 8.581,  'eval_samples_per_second': 130.988,  'eval_steps_per_second': 13.169,  'epoch': 3.0},
                 {'eval_loss': 1.6106154918670654,  'eval_accuracy': 0.7891459074733096,  'eval_f1': 0.6775510204081633,  'eval_f1 macro': 0.7604542940771815,  'eval_precision': 0.664,  'eval_recall': 0.6916666666666667,  'eval_runtime': 8.5199,  'eval_samples_per_second': 131.926,  'eval_steps_per_second': 13.263,  'epoch': 3.0},
                 {'eval_loss': 1.6279417276382446,  'eval_accuracy': 0.7909252669039146,  'eval_f1': 0.6676096181046676,  'eval_f1 macro': 0.7575556202139171,  'eval_precision': 0.6801152737752162,  'eval_recall': 0.6555555555555556,  'eval_runtime': 8.4836,  'eval_samples_per_second': 132.492,  'eval_steps_per_second': 13.32,  'epoch': 3.0},
                 {'eval_loss': 1.8647515773773193,  'eval_accuracy': 0.7855871886120996,  'eval_f1': 0.6522366522366523,  'eval_f1 macro': 0.7486263647035352,  'eval_precision': 0.6786786786786787,  'eval_recall': 0.6277777777777778,  'eval_runtime': 8.4761,  'eval_samples_per_second': 132.609,  'eval_steps_per_second': 13.332,  'epoch': 3.0},
                 {'eval_loss': 1.8071463108062744,  'eval_accuracy': 0.7900355871886121,  'eval_f1': 0.6740331491712707,  'eval_f1 macro': 0.7595887530633256,  'eval_precision': 0.6703296703296703,  'eval_recall': 0.6777777777777778,  'eval_runtime': 8.4905,  'eval_samples_per_second': 132.383,  'eval_steps_per_second': 13.309,  'epoch': 3.0},
                 {'eval_loss': 1.826467752456665,  'eval_accuracy': 0.7758007117437722,  'eval_f1': 0.6594594594594594,  'eval_f1 macro': 0.7461753530719047,  'eval_precision': 0.6421052631578947,  'eval_recall': 0.6777777777777778,  'eval_runtime': 8.4646,  'eval_samples_per_second': 132.788,  'eval_steps_per_second': 13.35,  'epoch': 3.0},
                 {'eval_loss': 1.9695992469787598,  'eval_accuracy': 0.7784697508896797,  'eval_f1': 0.6437768240343348,  'eval_f1 macro': 0.7415139768977355,  'eval_precision': 0.6637168141592921,  'eval_recall': 0.625,  'eval_runtime': 8.5064,  'eval_samples_per_second': 132.136,  'eval_steps_per_second': 13.284,  'epoch': 3.0},
                 {'eval_loss': 1.8869869709014893,  'eval_accuracy': 0.7855871886120996,  'eval_f1': 0.665742024965326,  'eval_f1 macro': 0.753958111369369,  'eval_precision': 0.6648199445983379,  'eval_recall': 0.6666666666666666,  'eval_runtime': 8.47,  'eval_samples_per_second': 132.704,  'eval_steps_per_second': 13.341,  'epoch': 3.0},
                 {'eval_loss': 1.8948405981063843,  'eval_accuracy': 0.7749110320284698,  'eval_f1': 0.6471408647140865,  'eval_f1 macro': 0.7409446975431961,  'eval_precision': 0.6498599439775911,  'eval_recall': 0.6444444444444445,  'eval_runtime': 8.5746,  'eval_samples_per_second': 131.085,  'eval_steps_per_second': 13.178,  'epoch': 3.0},
                 {'eval_loss': 2.0815534591674805,  'eval_accuracy': 0.7660142348754448,  'eval_f1': 0.6450742240215924,  'eval_f1 macro': 0.7352776561382017,  'eval_precision': 0.6272965879265092,  'eval_recall': 0.6638888888888889,  'eval_runtime': 8.5075,  'eval_samples_per_second': 132.119,  'eval_steps_per_second': 13.282,  'epoch': 3.0}]

# %%
results_roberta = [ {'eval_loss': 0.9526160955429077, 'eval_accuracy': 0.7882562277580071, 'eval_f1': 0.6638418079096046, 'eval_f1 macro': 0.7546481766820751, 'eval_precision': 0.6752873563218391, 'eval_recall': 0.6527777777777778, 'eval_runtime': 21.0947, 'eval_samples_per_second': 53.283, 'eval_steps_per_second': 5.357, 'epoch': 3.0},
                    {'eval_loss': 1.3310396671295166, 'eval_accuracy': 0.7953736654804271, 'eval_f1': 0.6823204419889503, 'eval_f1 macro': 0.7657009034091733, 'eval_precision': 0.6785714285714286, 'eval_recall': 0.6861111111111111, 'eval_runtime': 21.2596, 'eval_samples_per_second': 52.87, 'eval_steps_per_second': 5.315, 'epoch': 3.0},
                    {'eval_loss': 1.6530230045318604, 'eval_accuracy': 0.7740213523131673, 'eval_f1': 0.6422535211267606, 'eval_f1 macro': 0.7385519881316507, 'eval_precision': 0.6514285714285715, 'eval_recall': 0.6333333333333333, 'eval_runtime': 21.0251, 'eval_samples_per_second': 53.46, 'eval_steps_per_second': 5.375, 'epoch': 3.0},
                    {'eval_loss': 1.5561916828155518, 'eval_accuracy': 0.7909252669039146, 'eval_f1': 0.6657183499288764, 'eval_f1 macro': 0.756807395029163, 'eval_precision': 0.6822157434402333, 'eval_recall': 0.65, 'eval_runtime': 21.029, 'eval_samples_per_second': 53.45, 'eval_steps_per_second': 5.374, 'epoch': 3.0},
                    {'eval_loss': 0.9774307012557983, 'eval_accuracy': 0.7838078291814946, 'eval_f1': 0.6572637517630465, 'eval_f1 macro': 0.7496845074604707, 'eval_precision': 0.667621776504298, 'eval_recall': 0.6472222222222223, 'eval_runtime': 19.6939, 'eval_samples_per_second': 57.073, 'eval_steps_per_second': 5.738, 'epoch': 3.0}]

# %%
results_electra = [{'eval_loss': 0.7311571836471558, 'eval_accuracy': 0.7473309608540926, 'eval_f1': 0.6223404255319149, 'eval_f1 macro': 0.7162504266697007, 'eval_precision': 0.5969387755102041, 'eval_recall': 0.65, 'eval_runtime': 6.2985, 'eval_samples_per_second': 178.454, 'eval_steps_per_second': 17.941, 'epoch': 3.0},
                   {'eval_loss': 1.8522388935089111, 'eval_accuracy': 0.7508896797153025, 'eval_f1': 0.6325459317585302, 'eval_f1 macro': 0.7220603144660753, 'eval_precision': 0.599502487562189, 'eval_recall': 0.6694444444444444, 'eval_runtime': 6.426, 'eval_samples_per_second': 174.916, 'eval_steps_per_second': 17.585, 'epoch': 3.0},
                   {'eval_loss': 0.7168567776679993, 'eval_accuracy': 0.7544483985765125, 'eval_f1': 0.6290322580645162, 'eval_f1 macro': 0.722760809883322, 'eval_precision': 0.609375, 'eval_recall': 0.65, 'eval_runtime': 6.3185, 'eval_samples_per_second': 177.889, 'eval_steps_per_second': 17.884, 'epoch': 3.0},
                   {'eval_loss': 1.2593778371810913, 'eval_accuracy': 0.7580071174377224, 'eval_f1': 0.6304347826086957, 'eval_f1 macro': 0.7252703013572579, 'eval_precision': 0.6170212765957447, 'eval_recall': 0.6444444444444445, 'eval_runtime': 6.4521, 'eval_samples_per_second': 174.208, 'eval_steps_per_second': 17.514, 'epoch': 3.0},
                   {'eval_loss': 1.713454008102417,  'eval_accuracy': 0.7437722419928826,  'eval_f1': 0.6149732620320855,  'eval_f1 macro': 0.7114866310160427,  'eval_precision': 0.5927835051546392,  'eval_recall': 0.6388888888888888,  'eval_runtime': 6.4648, 'eval_samples_per_second': 173.865,  'eval_steps_per_second': 17.479,  'epoch': 3.0},
                   {'eval_loss': 0.7130807042121887,  'eval_accuracy': 0.75355871886121,  'eval_f1': 0.6301735647530039,  'eval_f1 macro': 0.7226918524231998,  'eval_precision': 0.6066838046272494,  'eval_recall': 0.6555555555555556,  'eval_runtime': 6.1816,  'eval_samples_per_second': 181.829,  'eval_steps_per_second': 18.28,  'epoch': 3.0},
                   {'eval_loss': 1.2702606916427612,  'eval_accuracy': 0.7597864768683275,  'eval_f1': 0.6493506493506495,  'eval_f1 macro': 0.7333356765021177,  'eval_precision': 0.6097560975609756,  'eval_recall': 0.6944444444444444,  'eval_runtime': 6.1013,  'eval_samples_per_second': 184.223,  'eval_steps_per_second': 18.521,  'epoch': 3.0},
                   {'eval_loss': 1.7108043432235718,  'eval_accuracy': 0.7544483985765125,  'eval_f1': 0.6424870466321243,  'eval_f1 macro': 0.7277475883567126,  'eval_precision': 0.6019417475728155,  'eval_recall': 0.6888888888888889,  'eval_runtime': 6.1745,  'eval_samples_per_second': 182.04,  'eval_steps_per_second': 18.301,'epoch': 3.0}]

# %%
results_bertin = [{'eval_loss': 1.8532356023788452, 'eval_accuracy': 0.7606761565836299, 'eval_f1': 0.6248256624825662, 'eval_f1 macro': 0.7245617535143072, 'eval_precision': 0.6274509803921569, 'eval_recall': 0.6222222222222222, 'eval_runtime': 20.4043, 'eval_samples_per_second': 55.086, 'eval_steps_per_second': 5.538, 'epoch': 3.0},
                  {'eval_loss': 1.924187421798706, 'eval_accuracy': 0.7669039145907474, 'eval_f1': 0.6570680628272251, 'eval_f1 macro': 0.7402590987990573, 'eval_precision': 0.6212871287128713, 'eval_recall': 0.6972222222222222, 'eval_runtime': 20.0912, 'eval_samples_per_second': 55.945, 'eval_steps_per_second': 5.624, 'epoch': 3.0},
                  {'eval_loss': 1.5898061990737915, 'eval_accuracy': 0.7758007117437722, 'eval_f1': 0.6519337016574586, 'eval_f1 macro': 0.7432896854743987, 'eval_precision': 0.6483516483516484, 'eval_recall': 0.6555555555555556, 'eval_runtime': 20.1065, 'eval_samples_per_second': 55.902, 'eval_steps_per_second': 5.62, 'epoch': 3.0},
                  {'eval_loss': 1.249072551727295, 'eval_accuracy': 0.7686832740213523, 'eval_f1': 0.6533333333333333, 'eval_f1 macro': 0.7398842901646641, 'eval_precision': 0.6282051282051282, 'eval_recall': 0.6805555555555556, 'eval_runtime': 20.1188, 'eval_samples_per_second': 55.868, 'eval_steps_per_second': 5.617, 'epoch': 3.0},
                  {'eval_loss': 0.8685683012008667, 'eval_accuracy': 0.7731316725978647, 'eval_f1': 0.6613545816733066, 'eval_f1 macro': 0.7453930099001984, 'eval_precision': 0.6335877862595419, 'eval_recall': 0.6916666666666667, 'eval_runtime': 20.1235, 'eval_samples_per_second': 55.855, 'eval_steps_per_second': 5.615, 'epoch': 3.0},
                  {'eval_loss': 0.9675100445747375, 'eval_accuracy': 0.7775800711743772, 'eval_f1': 0.6438746438746438, 'eval_f1 macro': 0.7410835056371925, 'eval_precision': 0.6608187134502924, 'eval_recall': 0.6277777777777778, 'eval_runtime': 21.1623, 'eval_samples_per_second': 53.113, 'eval_steps_per_second': 5.34, 'epoch': 3.0},
                  {'eval_loss': 1.5032063722610474, 'eval_accuracy': 0.7624555160142349, 'eval_f1': 0.638700947225981, 'eval_f1 macro': 0.7308812887223344, 'eval_precision': 0.6226912928759895, 'eval_recall': 0.6555555555555556, 'eval_runtime': 21.245, 'eval_samples_per_second': 52.906, 'eval_steps_per_second': 5.319, 'epoch': 3.0}]

# %%
results_dict = {
    "roberta": results_roberta,
    "beto": results_beto,
    "electra": results_electra,
    "bertin": results_bertin
}

# %%
import json
f = open('data/results.json')
results_dict = json.load(f)

# %%
metric_names = ['accuracy', 'precision', 'f1', 'f1 macro', 'recall']

model_metrics = {}

for model_name in results_dict.keys():
    model_results = results_dict[model_name]
    model_metrics[model_name] = {}
    for metric_name in metric_names:
        metric_list = []
        for result in model_results:
            metric_list.append(result['eval_' + metric_name])
        model_metrics[model_name][metric_name] = metric_list

# %% [markdown]
# ### Grafico métricas
#
# Beto y Roberta son a priori los mejores modelos. A excepción de en Recall, Roberta supera a Beto en todos los casos. Electra tiene métricas reiteradamente malas.

# %%
metrics = ['accuracy', 'precision', 'f1','f1 macro', 'recall']
models = ['beto', 'roberta', 'electra', 'bertin', 'robertuito']

for metric in metrics:
    fig, ax = plt.subplots()
    means = []
    stds = []
    for model in models:
        data = model_metrics[model][metric]
        mean = np.mean(data)
        std = np.std(data)
        means.append(mean)
        stds.append(std)
    ax.errorbar(x=models, y=means, yerr=stds, fmt='o', capsize=10)
    ax.set_xticklabels([x.capitalize() for x in models])
    ax.set_title(f"Mean {metric.capitalize()} with Standard Deviation")
    ax.set_ylabel(metric.capitalize())
    ax.xaxis.grid(False)
    plt.show()
# Out:
# C:\Users\Pluvini\AppData\Local\Temp\ipykernel_4432\3074656940.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([x.capitalize() for x in models])
